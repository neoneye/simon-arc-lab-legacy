# %%
# !pip install sympy
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Pygments-2.15.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Pygments-2.15.1.dist-info due to invalid metadata entry 'name'
# ...
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# ...

# %%
from sympy import prime
import matplotlib.pyplot as plt
import math

values = []
for i in range(500):
    #value = prime(i + 1)
    #value = (prime(i + 1) * (i+1)) // prime(i + 2) - i # not in oeis
    #value = (prime(i + 2) * (i+1)) // prime(i + 1) - i # not in oeis
    #value = (prime(i + 2) * (i)) // prime(i + 1) - i # not in oeis
    #value = (prime(i + 2) * (prime(i + 1) % (i + 1))) // prime(i + 1) - i # not in oeis
    #value = (prime(i + 2) * (prime(i + 2) % (i + 1))) // prime(i + 1) - i # not in oeis
    #value = (1 * ((prime(i + 2) ** 2 - i) % prime(i + 1))) #// prime(i + 2)
    #value = ((((prime(i + 1) ** 3)) % (i + 1))) # similar to https://oeis.org/A178211
    #value = ((((prime(i + 1) ** 3)) % (1000)))
    #value = ((((math.pow(prime(i + 1), math.pi))) % (math.pi)))
    #value = (((((prime(i + 1) * math.pi))) % (100)))
    #value = (((((prime(i + 1) * math.e))) % prime(i + 2)))
    #value = (((prime(i + 1) * math.pi))) % (math.pi + prime(i + 1))
    #value = (((prime(i + 1) * math.e))) % (i + 1)
    #value = (((prime(i + 1) * math.pi))) % (i + 1)
    #value = ((((i + 1) ** math.pi))) % prime(i + 1)
    #value = (((prime(i + 1) ** math.e))) % prime(i + 1)
    #value = (((prime(i + 1) ** math.pi))) % prime(i + 1)
    #value = (((prime(i + 1) ** math.e))) % math.isqrt(prime(i + 1))
    #value = (((prime((i + 1) * 2)))) % math.sqrt(prime(i + 1) * math.pi)
    #value = ((((i + 1) - i) ** 2) + i) % (i + 1)
    #value = (((((i ** 2))))) % math.sqrt(prime(i + 1) * math.pi)
    #value = ((((prime(i + 2))))) / (math.isqrt(prime(i + 1) * prime(i + 3)) + 1)
    value = (math.isqrt(i) + math.isqrt(i+1)) ** 2 # not in oeis
    #value = (math.sqrt(i) + math.sqrt(i+1)) ** 2
    values.append(value)

# Create the plot
plt.figure(figsize=(10, 5))
plt.scatter(range(0, len(values)), values, c='blue', s=5)
#plt.title("First 100 Prime Numbers")
#plt.xlabel("Index")
#plt.ylabel("Prime Numbers")
#plt.grid(True)
plt.show()

print(values)
# Out:
# [1, 4, 4, 9, 16, 16, 16, 16, 25, 36, 36, 36, 36, 36, 36, 49, 64, 64, 64, 64, 64, 64, 64, 64, 81, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 121, 144, 144, 144, 144, 144, 144, 144, 144, 144, 144, 144, 144, 169, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 225, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 289, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 324, 361, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 441, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 484, 529, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 576, 625, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 676, 729, 784, 784, 784, 784, 784, 784, 784, 784, 784, 7
# ...
